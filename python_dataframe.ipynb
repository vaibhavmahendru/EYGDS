# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavmahendru/EYGDS/blob/main/python_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import datetime

# %%
students  = ['Alex' , 'Bob' , 'Max' , 'James']

# %%
scores = [55 , 65 , 88 , 78]

# %%
exam_grades = pd.DataFrame(
    {
        "name" : students,
        "scores" : scores
    }
)

# %%
exam_grades
# Out:
#     name  scores
# 0   Alex      55
# 1    Bob      65
# 2    Max      88
# 3  James      78

# %%
exam_grades.loc[0,'scores']
# Out:
# 55

# %%
exam_grades.loc[:,'scores']
# Out:
# 0    55
# 1    65
# 2    88
# 3    78
# Name: scores, dtype: int64

# %%
exam_grades.loc[2,:]
# Out:
# name      Max
# scores     88
# Name: 2, dtype: object

# %%
exam_grades["scores"]
# Out:
# 0    55
# 1    65
# 2    88
# 3    78
# Name: scores, dtype: int64

# %%
exam_grades["name"]
# Out:
# 0     Alex
# 1      Bob
# 2      Max
# 3    James
# Name: name, dtype: object

# %%
gender = ['female' , 'male' , 'female' , 'male']

# %%
exam_grades['gender'] = gender

# %%
exam_grades
# Out:
#     name  scores  gender
# 0   Alex      55  female
# 1    Bob      65    male
# 2    Max      88  female
# 3  James      78    male

# %%
exam_grades['gender']
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# Name: gender, dtype: object

# %%
exam_grades.drop('name' , axis=1)
# Out:
#    scores  gender
# 0      55  female
# 1      65    male
# 2      88  female
# 3      78    male

# %%
exam_grades
# Out:
#     name  scores  gender
# 0   Alex      55  female
# 1    Bob      65    male
# 2    Max      88  female
# 3  James      78    male

# %%
exam_grades.columns
# Out:
# Index(['name', 'scores', 'gender'], dtype='object')

# %%
exam_grades.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   scores  4 non-null      int64
#  2   gender  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
exam_grades.describe()
# Out:
#           scores
# count   4.000000
# mean   71.500000
# std    14.479871
# min    55.000000
# 25%    62.500000
# 50%    71.500000
# 75%    80.500000
# max    88.000000

# %%
exam_grades.rename({'name' : 'firstname'}, axis=1)
# Out:
#   firstname  scores  gender
# 0      Alex      55  female
# 1       Bob      65    male
# 2       Max      88  female
# 3     James      78    male

# %%
sparse = pd.DataFrame(
    {
        'a' : [1,2,3],
        'b' : [np.nan , 4,np.nan],
        'c' : [5,np.nan,np.nan]
    }
)

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.isna()
# Out:
#        a      b      c
# 0  False   True  False
# 1  False  False   True
# 2  False   True   True

# %%
sparse.fillna(8)
# Out:
#    a    b    c
# 0  1  8.0  5.0
# 1  2  4.0  8.0
# 2  3  8.0  8.0

# %%
sparse
# Out:
#    a    b    c
# 0  1  NaN  5.0
# 1  2  4.0  NaN
# 2  3  NaN  NaN

# %%
sparse.dropna(axis = 1)
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %%
exam_grades.groupby('gender').mean()
# Out:
#         scores
# gender
# female    71.5
# male      71.5

# %%
exam_grades
# Out:
#     name  scores  gender
# 0   Alex      55  female
# 1    Bob      65    male
# 2    Max      88  female
# 3  James      78    male

# %%
mylist=[1,2,1,2]

exam_grades.groupby(mylist).get_group(1)
# Out:
#    name  scores  gender
# 0  Alex      55  female
# 2   Max      88  female

# %%
exam_grades.groupby(mylist).get_group(2)
# Out:
#     name  scores gender
# 1    Bob      65   male
# 3  James      78   male

# %%
above_70 = exam_grades['scores'] > 70
above_70
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: scores, dtype: bool

# %%
exam_grades
# Out:
#     name  scores  gender
# 0   Alex      55  female
# 1    Bob      65    male
# 2    Max      88  female
# 3  James      78    male

# %%
exam_grades.groupby(above_70).mean()
# Out:
#         scores
# scores
# False     60.0
# True      83.0

# %%
contacts = pd.DataFrame(
    {
     'name' :['Bob','Charlie'] ,
     'Tel'  :['+91 999 999 99 99', '+91 888 888 88 88'] 
    }
)

# %%
exam_grades.merge(contacts , left_on ='name' , right_on = 'name')
# Out:
#   name  scores gender                Tel
# 0  Bob      65   male  +91 999 999 99 99

# %%
exam_grades.merge(contacts , left_on ='name' , right_on = 'name' , how = 'outer')
# Out:
#       name  scores  gender                Tel
# 0     Alex    55.0  female                NaN
# 1      Bob    65.0    male  +91 999 999 99 99
# 2      Max    88.0  female                NaN
# 3    James    78.0    male                NaN
# 4  Charlie     NaN     NaN  +91 888 888 88 88
